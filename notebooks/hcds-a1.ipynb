# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Read the CSV Files

# %%
page_data = pd.read_csv("../data/page_data.csv")
page_data.head()
# Out:
#                                  page   country     rev_id
# 0  Template:ZambiaProvincialMinisters    Zambia  235107991
# 1                      Bir I of Kanem      Chad  355319463
# 2   Template:Zimbabwe-politician-stub  Zimbabwe  391862046
# 3     Template:Uganda-politician-stub    Uganda  391862070
# 4    Template:Namibia-politician-stub   Namibia  391862409

# %%
population = pd.read_csv("../data/WPDS_2020_data - WPDS_2020_data.csv")
population.head()
# Out:
#               FIPS             Name        Type  TimeFrame  Data (M)  \
# 0            WORLD            WORLD       World       2019  7772.850
# 1           AFRICA           AFRICA  Sub-Region       2019  1337.918
# 2  NORTHERN AFRICA  NORTHERN AFRICA  Sub-Region       2019   244.344
# 3               DZ          Algeria     Country       2019    44.357
# 4               EG            Egypt     Country       2019   100.803
#
#    Population
# 0  7772850000
# 1  1337918000
# 2   244344000
# 3    44357000
# 4   100803000

# %% [markdown]
#  # Data Processing

# %% [markdown]
# The page_data contains some page names that start with the string "Template:". These pages are not Wikipedia articles, and should not be included in your analysis.

# %%
# Filter out the data with page names starting with "Template:"
page_data = page_data[~page_data['page'].str.startswith('Template:')]
# Reset the index
page_data.reset_index(drop=True, inplace=True)
page_data.head()
# Out:
#                                                 page                country  \
# 0                                     Bir I of Kanem                   Chad
# 1  Information Minister of the Palestinian Nation...  Palestinian Territory
# 2                                            Yos Por               Cambodia
# 3                                       Julius Gregr         Czech Republic
# 4                                       Edvard Gregr         Czech Republic
#
#       rev_id
# 0  355319463
# 1  393276188
# 2  393822005
# 3  395521877
# 4  395526568

# %% [markdown]
# WPDS_2020_data.csv contains some rows that provide cumulative regional population counts, rather than country-level counts. These rows are distinguished by having ALL CAPS values in the 'geography' field (e.g. AFRICA, OCEANIA). These rows won't match the country values in page_data.csv.

# %%
# Get the population of countries. (Excluding cumulative regional counts)
population_country = population[population['Type'] == 'Country']
population_country.reset_index(drop=True, inplace=True)
population_country.head()
# Out:
#   FIPS     Name     Type  TimeFrame  Data (M)  Population
# 0   DZ  Algeria  Country       2019    44.357    44357000
# 1   EG    Egypt  Country       2019   100.803   100803000
# 2   LY    Libya  Country       2019     6.891     6891000
# 3   MA  Morocco  Country       2019    35.952    35952000
# 4   SD    Sudan  Country       2019    43.849    43849000

# %% [markdown]
# # Obtain article quality

# %% [markdown]
# Now you need to get the predicted quality scores for each article in the Wikipedia dataset. We're using a machine learning system called ORES. This was originally an acronym for "Objective Revision Evaluation Service" but was simply renamed “ORES”. ORES is a machine learning tool that can provide estimates of Wikipedia article quality. The article quality estimates are, from best to worst:
#
# FA - Featured article
# GA - Good article
# B - B-class article
# C - C-class article
# Start - Start-class article
# Stub - Stub-class article
#
# These were learned based on articles in Wikipedia that were peer-reviewed using the Wikipedia content assessment procedures.These quality classes are a sub-set of quality assessment categories developed by Wikipedia editors. For this assignment, you only need to know that these categories exist, and that ORES will assign one of these 6 categories to any rev_id you send it.
#
# In order to get article predictions for each article in the Wikipedia dataset, you will first need to read page_data.csv into Python (or R), and then read through the dataset line by line, using the value of the rev_id column to make an API query.

# %%
# Obtain rev_ids as a list
rev_ids = page_data['rev_id'].tolist()

# %%
import requests

headers = {
    'User-Agent': 'https://github.com/azhou5211',
    'From': 'ajz55@uw.edu'
}

def api_call(endpoint, rev_id):
    """
    Function used to call API. Will return response.
    
    :param endpoint: API URL endpoint
    :param parameters: Parameter settings in the API call
    """
    call = requests.get(endpoint.format(rev_id=rev_id), headers=headers)
    response = call.json()
    return response

# %%
request_url = 'https://ores.wikimedia.org/v3/scores/enwiki/{rev_id}/articlequality'

# %%
# Get the article quality for each wikipedia article
article_quality = []
for rev_id in rev_ids:
    response = api_call(request_url, rev_id)
    try:
        pred = response['enwiki']['scores'][str(rev_id)]['articlequality']['score']['prediction']
    except:
        pred = np.nan
    article_quality.append(pred)

# %%
# Add the article quality into the pages dataframe
page_data['quality'] = article_quality
page_data.head()
# Out:
#                                                 page                country  \
# 0                                     Bir I of Kanem                   Chad
# 1  Information Minister of the Palestinian Nation...  Palestinian Territory
# 2                                            Yos Por               Cambodia
# 3                                       Julius Gregr         Czech Republic
# 4                                       Edvard Gregr         Czech Republic
#
#       rev_id quality
# 0  355319463    Stub
# 1  393276188    Stub
# 2  393822005    Stub
# 3  395521877    Stub
# 4  395526568    Stub

# %% [markdown]
# List of wikipedia pages that did not have a predicted quality from the ORES

# %%
# List of wikipedia pages that did not have a predicted quality from ORES
page_data[page_data['quality'].isna()]
# Out:
#                                  page         country     rev_id quality
# 14      List of politicians in Poland          Poland  516633096     NaN
# 21                         Tingtingru         Vanuatu  550682925     NaN
# 51                        Daud Arsala     Afghanistan  627547024     NaN
# 75     Book:Two Political Biographies           India  636911471     NaN
# 180                       Dilaver Bey          Turkey  669987106     NaN
# ...                               ...             ...        ...     ...
# 46287          John Rose (Trotskyist)  United Kingdom  807336308     NaN
# 46367                  Jalal Movaghar            Iran  807367030     NaN
# 46368                 Mohsen Movaghar            Iran  807367166     NaN
# 46686                  King Gutierrez     Philippines  807479587     NaN
# 46700                 Ajay Kannoujiya           India  807484325     NaN
#
# [276 rows x 4 columns]

# %%
page_data[page_data['quality'].isna()].to_csv("Non-Predicted ORES pages.csv", index=False)

# %% [markdown]
# Filter the page_data to include only the values that have a predicted quality

# %%
page_data_filtered = page_data[~page_data['quality'].isna()]
page_data_filtered
# Out:
#                                                     page  \
# 0                                         Bir I of Kanem
# 1      Information Minister of the Palestinian Nation...
# 2                                                Yos Por
# 3                                           Julius Gregr
# 4                                           Edvard Gregr
# ...                                                  ...
# 46695                                        Hal Bidlack
# 46696                                       Yahya Jammeh
# 46697                                   Lucius Fairchild
# 46698                               Fahd of Saudi Arabia
# 46699                                  Francis Fessenden
#
#                      country     rev_id quality
# 0                       Chad  355319463    Stub
# 1      Palestinian Territory  393276188    Stub
# 2                   Cambodia  393822005    Stub
# 3             Czech Republic  395521877    Stub
# 4             Czech Republic  395526568    Stub
# ...                      ...        ...     ...
# 46695          United States  807481636       C
# 46696                 Gambia  807482007      GA
# 46697          United States  807483006       C
# 46698           Saudi Arabia  807483153      GA
# 46699          United States  807483270       C
#
# [46425 rows x 4 columns]

# %% [markdown]
# # Combining the datasets

# %% [markdown]
# Merge the wikipedia data and population data together.
# Both have fields containing country names for just that purpose. After merging the data, you'll invariably run into entries which cannot be merged. Either the population dataset does not have an entry for the equivalent Wikipedia country, or vise versa.

# %%
df = page_data_filtered.merge(population_country, left_on='country', right_on='Name', how='left')
df
# Out:
#                                                     page  \
# 0                                         Bir I of Kanem
# 1      Information Minister of the Palestinian Nation...
# 2                                                Yos Por
# 3                                           Julius Gregr
# 4                                           Edvard Gregr
# ...                                                  ...
# 46420                                        Hal Bidlack
# 46421                                       Yahya Jammeh
# 46422                                   Lucius Fairchild
# 46423                               Fahd of Saudi Arabia
# 46424                                  Francis Fessenden
#
#                      country     rev_id quality FIPS                   Name  \
# 0                       Chad  355319463    Stub   TD                   Chad
# 1      Palestinian Territory  393276188    Stub   PS  Palestinian Territory
# 2                   Cambodia  393822005    Stub   KH               Cambodia
# 3             Czech Republic  395521877    Stub  NaN                    NaN
# 4             Czech Republic  395526568    Stub  NaN                    NaN
# ...                      ...        ...     ...  ...                    ...
# 46420          United States  807481636       C   US          United States
# 46421                 Gambia  807482007      GA   GM                 Gambia
# 46422          United States  807483006       C   US          United States
# 46423           Saudi Arabia  807483153      GA   SA           Saudi Arabia
# 46424          United States  807483270       C   US          United States
#
#           Type  TimeFrame  Data (M)   Population
# 0      Country     2019.0    16.877   16877000.0
# 1      Country     2019.0     5.008    5008000.0
# 2      Country     2019.0    15.497   15497000.0
# 3          NaN        NaN       NaN          NaN
# 4          NaN        NaN       NaN          NaN
# ...        ...        ...       ...          ...
# 46420  Country     2019.0   329.878  329878000.0
# 46421  Country     2019.0     2.417    2417000.0
# 46422  Country     2019.0   329.878  329878000.0
# 46423  Country     2019.0    35.041   35041000.0
# 46424  Country     2019.0   329.878  329878000.0
#
# [46425 rows x 10 columns]

# %% [markdown]
# Filter to only the relevant columns

# %%
df = df[['country','page','rev_id','quality','Population']]
df.rename(columns={'page':'article_name','rev_id':'revision_id','quality':'article_quality_est.','Population':'population'}, inplace=True)
df
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                      country  \
# 0                       Chad
# 1      Palestinian Territory
# 2                   Cambodia
# 3             Czech Republic
# 4             Czech Republic
# ...                      ...
# 46420          United States
# 46421                 Gambia
# 46422          United States
# 46423           Saudi Arabia
# 46424          United States
#
#                                             article_name  revision_id  \
# 0                                         Bir I of Kanem    355319463
# 1      Information Minister of the Palestinian Nation...    393276188
# 2                                                Yos Por    393822005
# 3                                           Julius Gregr    395521877
# 4                                           Edvard Gregr    395526568
# ...                                                  ...          ...
# 46420                                        Hal Bidlack    807481636
# 46421                                       Yahya Jammeh    807482007
# 46422                                   Lucius Fairchild    807483006
# 46423                               Fahd of Saudi Arabia    807483153
# 46424                                  Francis Fessenden    807483270
#
#       article_quality_est.   population
# 0                     Stub   16877000.0
# 1                     Stub    5008000.0
# 2                     Stub   15497000.0
# 3                     Stub          NaN
# 4                     Stub          NaN
# ...                    ...          ...
# 46420                    C  329878000.0
# 46421                   GA    2417000.0
# 46422                    C  329878000.0
# 46423                   GA   35041000.0
# 46424                    C  329878000.0
#
# [46425 rows x 5 columns]

# %% [markdown]
# Filter the rows that do not have data and output it to
# ```wp_wpds_countries-no_match.csv```

# %%
df[df['population'].isna()].to_csv("../output_files/wp_wpds_countries-no_match.csv", index=False)
df[df['population'].isna()]
# Out:
#                    country               article_name  revision_id  \
# 3           Czech Republic               Julius Gregr    395521877
# 4           Czech Republic               Edvard Gregr    395526568
# 29              Salvadoran           Timoteo Menéndez    566504165
# 31               Rhodesian                Gervas Clay    574571582
# 34     Congo, Dem. Rep. of               Mavua Mudima    592289232
# ...                    ...                        ...          ...
# 46306              Hondura    Juan Ángel Arias Boquín    807445333
# 46308              Hondura    Francisco Zelaya y Ayes    807445395
# 46322                Omani  Haitham bin Tariq Al Said    807451487
# 46326              Chechen           Ruslan Yamadayev    807454176
# 46365       Czech Republic            Vladimír Špidla    807462107
#
#       article_quality_est.  population
# 3                     Stub         NaN
# 4                     Stub         NaN
# 29                    Stub         NaN
# 31                    Stub         NaN
# 34                    Stub         NaN
# ...                    ...         ...
# 46306                Start         NaN
# 46308                 Stub         NaN
# 46322                 Stub         NaN
# 46326                    B         NaN
# 46365                    C         NaN
#
# [1857 rows x 5 columns]

# %% [markdown]
# Filter the df to contain non null values. Output the dataframe to ```wp_wpds_politicians_by_country.csv```

# %%
df = df[~df['population'].isna()]
df.to_csv("../output_files/wp_wpds_politicians_by_country.csv", index=False)
df
# Out:
#                      country  \
# 0                       Chad
# 1      Palestinian Territory
# 2                   Cambodia
# 5                     Canada
# 6                      Egypt
# ...                      ...
# 46420          United States
# 46421                 Gambia
# 46422          United States
# 46423           Saudi Arabia
# 46424          United States
#
#                                             article_name  revision_id  \
# 0                                         Bir I of Kanem    355319463
# 1      Information Minister of the Palestinian Nation...    393276188
# 2                                                Yos Por    393822005
# 5                                    Robert Douglas Cook    401577829
# 6                         List of Grand Viziers of Egypt    442937236
# ...                                                  ...          ...
# 46420                                        Hal Bidlack    807481636
# 46421                                       Yahya Jammeh    807482007
# 46422                                   Lucius Fairchild    807483006
# 46423                               Fahd of Saudi Arabia    807483153
# 46424                                  Francis Fessenden    807483270
#
#       article_quality_est.   population
# 0                     Stub   16877000.0
# 1                     Stub    5008000.0
# 2                     Stub   15497000.0
# 5                     Stub   38190000.0
# 6                     Stub  100803000.0
# ...                    ...          ...
# 46420                    C  329878000.0
# 46421                   GA    2417000.0
# 46422                    C  329878000.0
# 46423                   GA   35041000.0
# 46424                    C  329878000.0
#
# [44568 rows x 5 columns]

# %% [markdown]
# # Analysis

# %% [markdown]
# Calculate the proportion (as a percentage) of articles-per-population and high-quality articles for each country AND for each geographic region.
# By "high quality" articles, in this case we mean the number of articles about politicians in a given country that ORES predicted would be in either the "FA" (featured article) or "GA" (good article) classes.

# %% [markdown]
# Filter the data to include only "high" quality articles

# %%
df_analysis = df[(df['article_quality_est.']=='FA') | (df['article_quality_est.']=='GA')]
df_analysis
# Out:
#             country                    article_name  revision_id  \
# 267          Panama                 Gumercinda Páez    680071857
# 2086        Myanmar                      Pho Hlaing    712325072
# 3717         Russia  Konstantin Kostin (politician)    718512855
# 6157       Tanzania              Kimweri ye Nyumbai    728211265
# 6175         France        Auguste-Nicolas Vaillant    728477569
# ...             ...                             ...          ...
# 46408   Philippines                     Aga Muhlach    807479087
# 46409          Fiji                    Elizabeth II    807479170
# 46419        Greece              George I of Greece    807481543
# 46421        Gambia                    Yahya Jammeh    807482007
# 46423  Saudi Arabia            Fahd of Saudi Arabia    807483153
#
#       article_quality_est.   population
# 267                     GA    4283000.0
# 2086                    GA   54704000.0
# 3717                    GA  146733000.0
# 6157                    GA   59734000.0
# 6175                    GA   64940000.0
# ...                    ...          ...
# 46408                   GA  109581000.0
# 46409                   FA     896000.0
# 46419                   FA   10700000.0
# 46421                   GA    2417000.0
# 46423                   GA   35041000.0
#
# [1028 rows x 5 columns]

# %% [markdown]
# Groupby country to get the count of high quality papers

# %%
df_analysis_country = df_analysis.groupby('country').agg({"article_quality_est.":'count', 'population':'first'})
df_analysis_country.rename(columns={"article_quality_est.":"count_of_high_quality"}, inplace=True)
df_analysis_country
# Out:
#              count_of_high_quality  population
# country
# Afghanistan                     13  38928000.0
# Albania                          3   2838000.0
# Algeria                          2  44357000.0
# Argentina                       16  45377000.0
# Armenia                          5   2956000.0
# ...                            ...         ...
# Vanuatu                          3    321000.0
# Venezuela                        3  28645000.0
# Vietnam                         13  96209000.0
# Yemen                            3  29826000.0
# Zimbabwe                         2  14863000.0
#
# [146 rows x 2 columns]

# %% [markdown]
# Calculate the percentage of articles per population

# %%
df_analysis_country['percentage_of_articles-per-population'] = df_analysis_country['count_of_high_quality']/df_analysis_country['population']
df_analysis_country
# Out:
#              count_of_high_quality  population  \
# country
# Afghanistan                     13  38928000.0
# Albania                          3   2838000.0
# Algeria                          2  44357000.0
# Argentina                       16  45377000.0
# Armenia                          5   2956000.0
# ...                            ...         ...
# Vanuatu                          3    321000.0
# Venezuela                        3  28645000.0
# Vietnam                         13  96209000.0
# Yemen                            3  29826000.0
# Zimbabwe                         2  14863000.0
#
#              percentage_of_articles-per-population
# country
# Afghanistan                           3.339499e-07
# Albania                               1.057082e-06
# Algeria                               4.508871e-08
# Argentina                             3.526015e-07
# Armenia                               1.691475e-06
# ...                                            ...
# Vanuatu                               9.345794e-06
# Venezuela                             1.047303e-07
# Vietnam                               1.351225e-07
# Yemen                                 1.005834e-07
# Zimbabwe                              1.345623e-07
#
# [146 rows x 3 columns]

# %% [markdown]
# Get the total count of articles and add it to the analysis dataframe

# %%
count_of_articles = df.groupby('country').agg({"article_quality_est.":'count'})
df_analysis_country = df_analysis_country.merge(count_of_articles, how="left", left_index=True, right_index=True)
df_analysis_country
# Out:
#              count_of_high_quality  population  \
# country
# Afghanistan                     13  38928000.0
# Albania                          3   2838000.0
# Algeria                          2  44357000.0
# Argentina                       16  45377000.0
# Armenia                          5   2956000.0
# ...                            ...         ...
# Vanuatu                          3    321000.0
# Venezuela                        3  28645000.0
# Vietnam                         13  96209000.0
# Yemen                            3  29826000.0
# Zimbabwe                         2  14863000.0
#
#              percentage_of_articles-per-population  article_quality_est.
# country
# Afghanistan                           3.339499e-07                   319
# Albania                               1.057082e-06                   456
# Algeria                               4.508871e-08                   116
# Argentina                             3.526015e-07                   491
# Armenia                               1.691475e-06                   193
# ...                                            ...                   ...
# Vanuatu                               9.345794e-06                    58
# Venezuela                             1.047303e-07                   130
# Vietnam                               1.351225e-07                   187
# Yemen                                 1.005834e-07                   116
# Zimbabwe                              1.345623e-07                   163
#
# [146 rows x 4 columns]

# %% [markdown]
# Calculate the percentage of high-quality articles

# %%
df_analysis_country['percentage_of_high-quality_articles'] = df_analysis_country['count_of_high_quality']/df_analysis_country['article_quality_est.']
df_analysis_country.rename(columns={'article_quality_est.':'total_count'}, inplace=True)
df_analysis_country
# Out:
#              count_of_high_quality  population  \
# country
# Afghanistan                     13  38928000.0
# Albania                          3   2838000.0
# Algeria                          2  44357000.0
# Argentina                       16  45377000.0
# Armenia                          5   2956000.0
# ...                            ...         ...
# Vanuatu                          3    321000.0
# Venezuela                        3  28645000.0
# Vietnam                         13  96209000.0
# Yemen                            3  29826000.0
# Zimbabwe                         2  14863000.0
#
#              percentage_of_articles-per-population  total_count  \
# country
# Afghanistan                           3.339499e-07          319
# Albania                               1.057082e-06          456
# Algeria                               4.508871e-08          116
# Argentina                             3.526015e-07          491
# Armenia                               1.691475e-06          193
# ...                                            ...          ...
# Vanuatu                               9.345794e-06           58
# Venezuela                             1.047303e-07          130
# Vietnam                               1.351225e-07          187
# Yemen                                 1.005834e-07          116
# Zimbabwe                              1.345623e-07          163
#
#              percentage_of_high-quality_articles
# country
# Afghanistan                             0.040752
# Albania                                 0.006579
# Algeria                                 0.017241
# Argentina                               0.032587
# Armenia                                 0.025907
# ...                                          ...
# Vanuatu                                 0.051724
# Venezuela                               0.023077
# Vietnam                                 0.069519
# Yemen                                   0.025862
# Zimbabwe                                0.012270
#
# [146 rows x 5 columns]

# %% [markdown]
# # Results

# %% [markdown]
# ### Top 10 countries by coverage: 10 highest-ranked countries in terms of number of politician articles as a proportion of country population

# %%
df_analysis_country.sort_values(by=['percentage_of_articles-per-population'], ascending=False).head(10)
# Out:
#              count_of_high_quality  population  \
# country
# Tuvalu                           4     10000.0
# Dominica                         1     72000.0
# Vanuatu                          3    321000.0
# Iceland                          2    368000.0
# Ireland                         25   5003000.0
# Montenegro                       2    622000.0
# Martinique                       1    356000.0
# Bhutan                           2    730000.0
# New Zealand                     13   4987000.0
# Romania                         42  19241000.0
#
#              percentage_of_articles-per-population  total_count  \
# country
# Tuvalu                                    0.000400           54
# Dominica                                  0.000014           12
# Vanuatu                                   0.000009           58
# Iceland                                   0.000005          201
# Ireland                                   0.000005          373
# Montenegro                                0.000003           72
# Martinique                                0.000003           34
# Bhutan                                    0.000003           33
# New Zealand                               0.000003          783
# Romania                                   0.000002          343
#
#              percentage_of_high-quality_articles
# country
# Tuvalu                                  0.074074
# Dominica                                0.083333
# Vanuatu                                 0.051724
# Iceland                                 0.009950
# Ireland                                 0.067024
# Montenegro                              0.027778
# Martinique                              0.029412
# Bhutan                                  0.060606
# New Zealand                             0.016603
# Romania                                 0.122449

# %% [markdown]
# ### Bottom 10 countries by coverage: 10 lowest-ranked countries in terms of number of politician articles as a proportion of country population

# %%
df_analysis_country.sort_values(by=['percentage_of_articles-per-population']).head(10)
# Out:
#             count_of_high_quality    population  \
# country
# India                          13  1.400100e+09
# Nigeria                         2  2.061400e+08
# Tanzania                        1  5.973400e+07
# Ethiopia                        2  1.149160e+08
# Bangladesh                      3  1.698090e+08
# Colombia                        1  4.944400e+07
# Uganda                          1  4.574100e+07
# Morocco                         1  3.595200e+07
# Brazil                          6  2.118120e+08
# China                          40  1.402385e+09
#
#             percentage_of_articles-per-population  total_count  \
# country
# India                                9.285051e-09          968
# Nigeria                              9.702144e-09          676
# Tanzania                             1.674088e-08          404
# Ethiopia                             1.740402e-08          101
# Bangladesh                           1.766691e-08          317
# Colombia                             2.022490e-08          285
# Uganda                               2.186222e-08          185
# Morocco                              2.781486e-08          206
# Brazil                               2.832701e-08          545
# China                                2.852284e-08         1129
#
#             percentage_of_high-quality_articles
# country
# India                                  0.013430
# Nigeria                                0.002959
# Tanzania                               0.002475
# Ethiopia                               0.019802
# Bangladesh                             0.009464
# Colombia                               0.003509
# Uganda                                 0.005405
# Morocco                                0.004854
# Brazil                                 0.011009
# China                                  0.035430

# %% [markdown]
# ### Top 10 countries by relative quality: 10 highest-ranked countries in terms of the relative proportion of politician articles that are of GA and FA-quality

# %%
df_analysis_country.sort_values(by=['percentage_of_high-quality_articles'], ascending=False).head(10)
# Out:
#                           count_of_high_quality  population  \
# country
# Korea, North                                  8  25779000.0
# Saudi Arabia                                 15  35041000.0
# Romania                                      42  19241000.0
# Central African Republic                      8   4830000.0
# Uzbekistan                                    3  34174000.0
# Mauritania                                    5   4650000.0
# Guatemala                                     7  18066000.0
# Dominica                                      1     72000.0
# Syria                                        10  19398000.0
# Benin                                         7  12209000.0
#
#                           percentage_of_articles-per-population  total_count  \
# country
# Korea, North                                       3.103301e-07           36
# Saudi Arabia                                       4.280700e-07          117
# Romania                                            2.182839e-06          343
# Central African Republic                           1.656315e-06           66
# Uzbekistan                                         8.778604e-08           28
# Mauritania                                         1.075269e-06           48
# Guatemala                                          3.874682e-07           83
# Dominica                                           1.388889e-05           12
# Syria                                              5.155171e-07          128
# Benin                                              5.733475e-07           91
#
#                           percentage_of_high-quality_articles
# country
# Korea, North                                         0.222222
# Saudi Arabia                                         0.128205
# Romania                                              0.122449
# Central African Republic                             0.121212
# Uzbekistan                                           0.107143
# Mauritania                                           0.104167
# Guatemala                                            0.084337
# Dominica                                             0.083333
# Syria                                                0.078125
# Benin                                                0.076923

# %% [markdown]
# ### Bottom 10 countries by relative quality: 10 lowest-ranked countries in terms of the relative proportion of politician articles that are of GA and FA-quality

# %%
df_analysis_country.sort_values(by=['percentage_of_high-quality_articles']).head(10)
# Out:
#              count_of_high_quality   population  \
# country
# Belgium                          1   11515000.0
# Tanzania                         1   59734000.0
# Switzerland                      1    8634000.0
# Nepal                            1   29996000.0
# Peru                             1   32824000.0
# Nigeria                          2  206140000.0
# Portugal                         1   10255000.0
# Colombia                         1   49444000.0
# Lithuania                        1    2794000.0
# Morocco                          1   35952000.0
#
#              percentage_of_articles-per-population  total_count  \
# country
# Belgium                               8.684325e-08          519
# Tanzania                              1.674088e-08          404
# Switzerland                           1.158212e-07          402
# Nepal                                 3.333778e-08          356
# Peru                                  3.046551e-08          350
# Nigeria                               9.702144e-09          676
# Portugal                              9.751341e-08          318
# Colombia                              2.022490e-08          285
# Lithuania                             3.579098e-07          244
# Morocco                               2.781486e-08          206
#
#              percentage_of_high-quality_articles
# country
# Belgium                                 0.001927
# Tanzania                                0.002475
# Switzerland                             0.002488
# Nepal                                   0.002809
# Peru                                    0.002857
# Nigeria                                 0.002959
# Portugal                                0.003145
# Colombia                                0.003509
# Lithuania                               0.004098
# Morocco                                 0.004854

# %% [markdown]
# Geographic regions by coverage: Ranking of geographic regions (in descending order) in terms of the total count of politician articles from countries in each region as a proportion of total regional population

# %% [markdown]
# Obtain the regions from the population dataframe

# %%
region = "NORTHERN AFRICA"

regions = ['WORLD', 'AFRICA', 'NORTHERN AFRICA']
for i in range(3, len(population)):
    if population.iloc[i]['Type']=='Sub-Region':
        region = population.iloc[i]['Name']
    regions.append(region)

# %%
population['Region'] = regions
population
# Out:
#                 FIPS             Name        Type  TimeFrame  Data (M)  \
# 0              WORLD            WORLD       World       2019  7772.850
# 1             AFRICA           AFRICA  Sub-Region       2019  1337.918
# 2    NORTHERN AFRICA  NORTHERN AFRICA  Sub-Region       2019   244.344
# 3                 DZ          Algeria     Country       2019    44.357
# 4                 EG            Egypt     Country       2019   100.803
# ..               ...              ...         ...        ...       ...
# 229               WS            Samoa     Country       2019     0.200
# 230               SB  Solomon Islands     Country       2019     0.715
# 231               TO            Tonga     Country       2019     0.099
# 232               TV           Tuvalu     Country       2019     0.010
# 233               VU          Vanuatu     Country       2019     0.321
#
#      Population           Region
# 0    7772850000            WORLD
# 1    1337918000           AFRICA
# 2     244344000  NORTHERN AFRICA
# 3      44357000  NORTHERN AFRICA
# 4     100803000  NORTHERN AFRICA
# ..          ...              ...
# 229      200000          OCEANIA
# 230      715000          OCEANIA
# 231       99000          OCEANIA
# 232       10000          OCEANIA
# 233      321000          OCEANIA
#
# [234 rows x 7 columns]

# %%
df_analysis_country.reset_index(inplace=True)

# %% [markdown]
# Merge the region with analysis

# %%
df_analysis_country_ = df_analysis_country.merge(population[['Name', 'Region']], left_on='country', right_on='Name', how='left')
df_analysis_country_.drop(columns=['Name'], inplace=True)
df_analysis_country_
# Out:
#      index      country  count_of_high_quality  population  \
# 0        0  Afghanistan                     13  38928000.0
# 1        1      Albania                      3   2838000.0
# 2        2      Algeria                      2  44357000.0
# 3        3    Argentina                     16  45377000.0
# 4        4      Armenia                      5   2956000.0
# ..     ...          ...                    ...         ...
# 141    141      Vanuatu                      3    321000.0
# 142    142    Venezuela                      3  28645000.0
# 143    143      Vietnam                     13  96209000.0
# 144    144        Yemen                      3  29826000.0
# 145    145     Zimbabwe                      2  14863000.0
#
#      percentage_of_articles-per-population  total_count  \
# 0                             3.339499e-07          319
# 1                             1.057082e-06          456
# 2                             4.508871e-08          116
# 3                             3.526015e-07          491
# 4                             1.691475e-06          193
# ..                                     ...          ...
# 141                           9.345794e-06           58
# 142                           1.047303e-07          130
# 143                           1.351225e-07          187
# 144                           1.005834e-07          116
# 145                           1.345623e-07          163
#
#      percentage_of_high-quality_articles           Region
# 0                               0.040752       SOUTH ASIA
# 1                               0.006579  SOUTHERN EUROPE
# 2                               0.017241  NORTHERN AFRICA
# 3                               0.032587    SOUTH AMERICA
# 4                               0.025907     WESTERN ASIA
# ..                                   ...              ...
# 141                             0.051724          OCEANIA
# 142                             0.023077    SOUTH AMERICA
# 143                             0.069519   SOUTHEAST ASIA
# 144                             0.025862     WESTERN ASIA
# 145                             0.012270   EASTERN AFRICA
#
# [146 rows x 8 columns]

# %% [markdown]
# Groupby region and sum the paper counts

# %%
df_analysis_region = df_analysis_country_.groupby('Region').agg({'count_of_high_quality':'sum','total_count':'sum'})
df_analysis_region
# Out:
#                   count_of_high_quality  total_count
# Region
# CARIBBEAN                            13          552
# CENTRAL AMERICA                      23         1380
# CENTRAL ASIA                          7          135
# Channel Islands                     102         3046
# EAST ASIA                            76         2473
# EASTERN AFRICA                       35         2294
# EASTERN EUROPE                      118         3311
# MIDDLE AFRICA                        16          538
# NORTHERN AFRICA                      19          761
# NORTHERN AMERICA                    104         1901
# OCEANIA                              63         2811
# SOUTH AMERICA                        40         2985
# SOUTH ASIA                           71         4366
# SOUTHEAST ASIA                       73         2020
# SOUTHERN AFRICA                       9          443
# SOUTHERN EUROPE                      74         3595
# WESTERN AFRICA                       40         2103
# WESTERN ASIA                         89         2521
# WESTERN EUROPE                       56         4492

# %% [markdown]
# Merge the population value

# %%
population_region = population[population['Type']=='Sub-Region']

# %%
df_analysis_region_ = df_analysis_region.merge(population_region[['Name', 'Population']], left_index=True, right_on='Name')
df_analysis_region_
# Out:
#      count_of_high_quality  total_count              Name  Population
# 77                      13          552         CARIBBEAN    43233000
# 68                      23         1380   CENTRAL AMERICA   178611000
# 129                      7          135      CENTRAL ASIA    74961000
# 168                    102         3046   Channel Islands      172000
# 157                     76         2473         EAST ASIA  1641063000
# 27                      35         2294    EASTERN AFRICA   444970000
# 189                    118         3311    EASTERN EUROPE   291902000
# 48                      16          538     MIDDLE AFRICA   179757000
# 2                       19          761   NORTHERN AFRICA   244344000
# 64                     104         1901  NORTHERN AMERICA   368193000
# 216                     63         2811           OCEANIA    43155000
# 95                      40         2985     SOUTH AMERICA   429191000
# 135                     71         4366        SOUTH ASIA  1967131000
# 145                     73         2020    SOUTHEAST ASIA   661845000
# 58                       9          443   SOUTHERN AFRICA    67732000
# 200                     74         3595   SOUTHERN EUROPE   153251000
# 10                      40         2103    WESTERN AFRICA   401115000
# 110                     89         2521      WESTERN ASIA   280927000
# 179                     56         4492    WESTERN EUROPE   195479000

# %% [markdown]
# Calculate percentage of articles-per-population and percentage of high-quality articles by region

# %%
df_analysis_region_['percentage_of_articles-per-population'] = df_analysis_region_['count_of_high_quality']/df_analysis_region_['Population']
df_analysis_region_['percentage_of_high-quality_articles'] = df_analysis_region_['count_of_high_quality']/df_analysis_region_['total_count']
df_analysis_region_ = df_analysis_region_[['Name', 'percentage_of_articles-per-population', 'percentage_of_high-quality_articles']]
df_analysis_region_.rename(columns={'Name':'Region'}, inplace=True)
df_analysis_region_
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                Region  percentage_of_articles-per-population  \
# 77          CARIBBEAN                           3.006962e-07
# 68    CENTRAL AMERICA                           1.287715e-07
# 129      CENTRAL ASIA                           9.338189e-08
# 168   Channel Islands                           5.930233e-04
# 157         EAST ASIA                           4.631145e-08
# 27     EASTERN AFRICA                           7.865699e-08
# 189    EASTERN EUROPE                           4.042453e-07
# 48      MIDDLE AFRICA                           8.900905e-08
# 2     NORTHERN AFRICA                           7.775922e-08
# 64   NORTHERN AMERICA                           2.824606e-07
# 216           OCEANIA                           1.459854e-06
# 95      SOUTH AMERICA                           9.319860e-08
# 135        SOUTH ASIA                           3.609317e-08
# 145    SOUTHEAST ASIA                           1.102977e-07
# 58    SOUTHERN AFRICA                           1.328766e-07
# 200   SOUTHERN EUROPE                           4.828680e-07
# 10     WESTERN AFRICA                           9.972202e-08
# 110      WESTERN ASIA                           3.168083e-07
# 179    WESTERN EUROPE                           2.864758e-07
#
#      percentage_of_high-quality_articles
# 77                              0.023551
# 68                              0.016667
# 129                             0.051852
# 168                             0.033487
# 157                             0.030732
# 27                              0.015257
# 189                             0.035639
# 48                              0.029740
# 2                               0.024967
# 64                              0.054708
# 216                             0.022412
# 95                              0.013400
# 135                             0.016262
# 145                             0.036139
# 58                              0.020316
# 200                             0.020584
# 10                              0.019020
# 110                             0.035303
# 179                             0.012467

# %% [markdown]
# ### Geographic regions by coverage: Ranking of geographic regions (in descending order) in terms of the total count of politician articles from countries in each region as a proportion of total regional population

# %%
df_analysis_region_.sort_values(by=['percentage_of_articles-per-population'], ascending=False)
# Out:
#                Region  percentage_of_articles-per-population  \
# 168   Channel Islands                           5.930233e-04
# 216           OCEANIA                           1.459854e-06
# 200   SOUTHERN EUROPE                           4.828680e-07
# 189    EASTERN EUROPE                           4.042453e-07
# 110      WESTERN ASIA                           3.168083e-07
# 77          CARIBBEAN                           3.006962e-07
# 179    WESTERN EUROPE                           2.864758e-07
# 64   NORTHERN AMERICA                           2.824606e-07
# 58    SOUTHERN AFRICA                           1.328766e-07
# 68    CENTRAL AMERICA                           1.287715e-07
# 145    SOUTHEAST ASIA                           1.102977e-07
# 10     WESTERN AFRICA                           9.972202e-08
# 129      CENTRAL ASIA                           9.338189e-08
# 95      SOUTH AMERICA                           9.319860e-08
# 48      MIDDLE AFRICA                           8.900905e-08
# 27     EASTERN AFRICA                           7.865699e-08
# 2     NORTHERN AFRICA                           7.775922e-08
# 157         EAST ASIA                           4.631145e-08
# 135        SOUTH ASIA                           3.609317e-08
#
#      percentage_of_high-quality_articles
# 168                             0.033487
# 216                             0.022412
# 200                             0.020584
# 189                             0.035639
# 110                             0.035303
# 77                              0.023551
# 179                             0.012467
# 64                              0.054708
# 58                              0.020316
# 68                              0.016667
# 145                             0.036139
# 10                              0.019020
# 129                             0.051852
# 95                              0.013400
# 48                              0.029740
# 27                              0.015257
# 2                               0.024967
# 157                             0.030732
# 135                             0.016262

# %% [markdown]
# ### Geographic regions by coverage: Ranking of geographic regions (in descending order) in terms of the relative proportion of politician articles from countries in each region that are of GA and FA-quality

# %%
df_analysis_region_.sort_values(by=['percentage_of_high-quality_articles'], ascending=False)
# Out:
#                Region  percentage_of_articles-per-population  \
# 64   NORTHERN AMERICA                           2.824606e-07
# 129      CENTRAL ASIA                           9.338189e-08
# 145    SOUTHEAST ASIA                           1.102977e-07
# 189    EASTERN EUROPE                           4.042453e-07
# 110      WESTERN ASIA                           3.168083e-07
# 168   Channel Islands                           5.930233e-04
# 157         EAST ASIA                           4.631145e-08
# 48      MIDDLE AFRICA                           8.900905e-08
# 2     NORTHERN AFRICA                           7.775922e-08
# 77          CARIBBEAN                           3.006962e-07
# 216           OCEANIA                           1.459854e-06
# 200   SOUTHERN EUROPE                           4.828680e-07
# 58    SOUTHERN AFRICA                           1.328766e-07
# 10     WESTERN AFRICA                           9.972202e-08
# 68    CENTRAL AMERICA                           1.287715e-07
# 135        SOUTH ASIA                           3.609317e-08
# 27     EASTERN AFRICA                           7.865699e-08
# 95      SOUTH AMERICA                           9.319860e-08
# 179    WESTERN EUROPE                           2.864758e-07
#
#      percentage_of_high-quality_articles
# 64                              0.054708
# 129                             0.051852
# 145                             0.036139
# 189                             0.035639
# 110                             0.035303
# 168                             0.033487
# 157                             0.030732
# 48                              0.029740
# 2                               0.024967
# 77                              0.023551
# 216                             0.022412
# 200                             0.020584
# 58                              0.020316
# 10                              0.019020
# 68                              0.016667
# 135                             0.016262
# 27                              0.015257
# 95                              0.013400
# 179                             0.012467
